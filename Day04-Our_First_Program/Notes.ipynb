# %% [markdown]
# # Python Tutorials Day 4

# %% [markdown]
# ## Our First Program
# It will consist of a bunch of print statements. ```print()``` can be used to print something on the console in python

# %% [markdown]
# ### Quiz
# Write a program to print a poem in Python. Choose the poem of your choice and publish your repl

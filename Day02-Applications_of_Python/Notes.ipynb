# %% [markdown]
# # Python Tutorials Day 2

# %% [markdown]
# Python can be used for a lot of purposes in DBMS, ML, AI, Data Analytics and a lot of other fields.

# %% [markdown]
# We will create Jarvis voice command, flappy birds and snake game in this course later.
